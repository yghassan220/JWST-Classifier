# %% [markdown]
# # 03 — Classification
# Train and evaluate a galaxy morphology classifier using transfer learning.
#
# **Goals:**
# - Load and explore the Galaxy Zoo dataset
# - Fine-tune a pretrained ResNet on morphology classes
# - Evaluate model performance
# - Run inference on JWST cutouts

# %%
import torch
import torch.nn as nn
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
import numpy as np
import matplotlib.pyplot as plt

# %%
# TODO: Load Galaxy Zoo dataset

# %%
# TODO: Build model

# %%
# TODO: Train

# %%
# TODO: Evaluate and run inference on JWST cutouts
