# %% [markdown]
# # 01 — Data Pipeline
# Query and download JWST FITS data from NASA's MAST archive.
#
# **Goals:**
# - Connect to MAST via astroquery
# - Query JWST observations by filter
# - Download and inspect a FITS file
# - Display the raw image correctly

# %%
from astroquery.mast import Observations
from astropy.io import fits
from astropy.visualization import ZScaleInterval
import matplotlib.pyplot as plt
import numpy as np

# %%
# TODO: Query JWST observations

# %%
# TODO: Download a FITS file

# %%
# TODO: Open and display the image
