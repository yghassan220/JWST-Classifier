# %% [markdown]
# # 02 — Source Detection
# Detect galaxy sources in preprocessed JWST images using photutils.
#
# **Goals:**
# - Estimate and subtract image background
# - Detect sources via image segmentation
# - Build a source catalog
# - Extract cutouts around detected galaxies

# %%
from photutils.background import Background2D, MedianBackground
from photutils.segmentation import detect_sources, SourceCatalog
from astropy.stats import sigma_clipped_stats
import matplotlib.pyplot as plt
import numpy as np

# %%
# TODO: Load preprocessed image

# %%
# TODO: Background estimation

# %%
# TODO: Source detection

# %%
# TODO: Extract and save cutouts
